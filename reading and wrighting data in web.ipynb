# %%
import urllib.request as req
import json
import pandas as pd

# %%
url = 'https://www.metaweather.com/api/location/search/?query=moscow'

# %%
session = req.urlopen(url)
response = session.read().decode()
session.close()
print(response)
# Out:
# [{"title":"Moscow","location_type":"City","woeid":2122265,"latt_long":"55.756950,37.614971"}]

# %%
with req.urlopen(url) as session:
    response = session.read().decode()
print(response)
# Out:
# [{"title":"Moscow","location_type":"City","woeid":2122265,"latt_long":"55.756950,37.614971"}]

# %%
data = json.loads(response)
print(data[0])
# Out:
# {'title': 'Moscow', 'location_type': 'City', 'woeid': 2122265, 'latt_long': '55.756950,37.614971'}

# %%
city = data[0]['woeid']
city
# Out:
# 2122265

# %%
url1 = 'https://www.metaweather.com/api/location/2122265/2020/07/20'

# %%
with req.urlopen(url1) as session:
    response = session.read().decode()
    data = json.loads(response)
data
# Out:
# [{'id': 4919777191526400,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-20T18:29:31.885101Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 16.794999999999998,
#   'max_temp': 24.02,
#   'the_temp': 23.005,
#   'wind_speed': 2.833971496858347,
#   'wind_direction': 300.6971747272375,
#   'air_pressure': 1011.5,
#   'humidity': 66,
#   'visibility': 12.808945756780403,
#   'predictability': 75},
#  {'id': 5843753002598400,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-20T15:29:31.460467Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 16.794999999999998,
#   'max_temp': 24.02,
#   'the_temp': 22.95,
#   'wind_speed': 2.833971496858347,
#   'wind_direction': 300.6971747272375,
#   'air_pressure': 1011.5,
#   'humidity': 66,
#   'visibility': 12.808945756780403,
#   'predictability': 73},
#  {'id': 4695383806574592,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-20T12:29:32.565565Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 16.724999999999998,
#   'max_temp': 23.92,
#   'the_temp': 21.939999999999998,
#   'wind_speed': 2.7411799186696357,
#   'wind_direction': 313.66663657794044,
#   'air_pressure': 1013.0,
#   'humidity': 71,
#   'visibility': 12.808945756780403,
#   'predictability': 73},
#  {'id': 4806990276591616,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-20T09:29:32.257786Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 16.84,
#   'max_temp': 22.765,
#   'the_temp': 21.9,
#   'wind_speed': 2.5419696853363027,
#   'wind_direction': 317.3299021184476,
#   'air_pressure': 1013.0,
#   'humidity': 71,
#   'visibility': 12.501367016622922,
#   'predictability': 73},
#  {'id': 6202314589208576,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-20T06:29:32.073897Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.115,
#   'max_temp': 21.955,
#   'the_temp': 20.64,
#   'wind_speed': 2.3568010490760627,
#   'wind_direction': 328.28048857461255,
#   'air_pressure': 1013.0,
#   'humidity': 69,
#   'visibility': 11.168215123677722,
#   'predictability': 75},
#  {'id': 5224521143418880,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-20T03:29:33.583986Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.375,
#   'max_temp': 22.18,
#   'the_temp': 20.68,
#   'wind_speed': 2.6234677157427293,
#   'wind_direction': 331.35398418937433,
#   'air_pressure': 1013.0,
#   'humidity': 70,
#   'visibility': 11.11508788674143,
#   'predictability': 75},
#  {'id': 5431512780505088,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-20T00:29:32.173478Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.614999999999998,
#   'max_temp': 23.05,
#   'the_temp': 20.93,
#   'wind_speed': 3.7846014417137255,
#   'wind_direction': 330.95708612705266,
#   'air_pressure': 1011.5,
#   'humidity': 64,
#   'visibility': 13.85129593175853,
#   'predictability': 75},
#  {'id': 4761532342730752,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T21:29:31.039087Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.614999999999998,
#   'max_temp': 23.05,
#   'the_temp': 21.065,
#   'wind_speed': 3.1284353083803924,
#   'wind_direction': 308.30386836234067,
#   'air_pressure': 1009.5,
#   'humidity': 66,
#   'visibility': 11.261420802513321,
#   'predictability': 75},
#  {'id': 4864295173095424,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T18:29:34.844031Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.675,
#   'max_temp': 19.725,
#   'the_temp': 20.22,
#   'wind_speed': 3.585032339526498,
#   'wind_direction': 324.95052346041354,
#   'air_pressure': 1012.5,
#   'humidity': 73,
#   'visibility': 9.874209615843473,
#   'predictability': 75},
#  {'id': 5888541458432000,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T15:29:33.982460Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.675,
#   'max_temp': 19.725,
#   'the_temp': 20.2,
#   'wind_speed': 3.577575906193165,
#   'wind_direction': 324.95052346041354,
#   'air_pressure': 1012.5,
#   'humidity': 74,
#   'visibility': 9.571912530820011,
#   'predictability': 75},
#  {'id': 5570326526164992,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T12:29:34.058569Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.649999999999999,
#   'max_temp': 19.1,
#   'the_temp': 20.064999999999998,
#   'wind_speed': 3.7432748907897877,
#   'wind_direction': 319.3329905781327,
#   'air_pressure': 1012.5,
#   'humidity': 74,
#   'visibility': 9.252527738010022,
#   'predictability': 77},
#  {'id': 6486747825307648,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T09:29:35.338169Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.3,
#   'max_temp': 18.674999999999997,
#   'the_temp': 19.99,
#   'wind_speed': 3.8716953574564545,
#   'wind_direction': 317.3299021184476,
#   'air_pressure': 1012.0,
#   'humidity': 73,
#   'visibility': 9.847801340173387,
#   'predictability': 77},
#  {'id': 6623753423290368,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T06:29:34.153016Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.975000000000001,
#   'max_temp': 18.86,
#   'the_temp': 19.49,
#   'wind_speed': 3.712624290296667,
#   'wind_direction': 315.9993901614561,
#   'air_pressure': 1012.0,
#   'humidity': 77,
#   'visibility': 9.149069434502504,
#   'predictability': 77},
#  {'id': 5377824447791104,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T03:29:34.547118Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.86,
#   'max_temp': 19.34,
#   'the_temp': 19.485,
#   'wind_speed': 3.9749935902966675,
#   'wind_direction': 313.0064297614647,
#   'air_pressure': 1012.0,
#   'humidity': 78,
#   'visibility': 8.328238089556987,
#   'predictability': 75},
#  {'id': 4958395121532928,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-19T00:29:35.849812Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.530000000000001,
#   'max_temp': 20.060000000000002,
#   'the_temp': 19.185000000000002,
#   'wind_speed': 4.226027824616241,
#   'wind_direction': 297.0,
#   'air_pressure': 1011.0,
#   'humidity': 75,
#   'visibility': 12.806149586415334,
#   'predictability': 75},
#  {'id': 4592018472828928,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-18T21:29:33.964414Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.530000000000001,
#   'max_temp': 20.060000000000002,
#   'the_temp': 19.16,
#   'wind_speed': 4.300592157949574,
#   'wind_direction': 303.0080158152948,
#   'air_pressure': 1009.0,
#   'humidity': 76,
#   'visibility': 11.870675256502029,
#   'predictability': 77},
#  {'id': 6497094837731328,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T18:29:38.189563Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.5,
#   'max_temp': 20.82,
#   'the_temp': 20.805,
#   'wind_speed': 3.792148521935894,
#   'wind_direction': 313.3338037204484,
#   'air_pressure': 1012.5,
#   'humidity': 69,
#   'visibility': 12.691817287043666,
#   'predictability': 75},
#  {'id': 5515548781707264,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T15:29:38.266512Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.5,
#   'max_temp': 20.82,
#   'the_temp': 20.77,
#   'wind_speed': 3.7623227886025608,
#   'wind_direction': 313.3338037204484,
#   'air_pressure': 1012.5,
#   'humidity': 70,
#   'visibility': 12.901840750019883,
#   'predictability': 75},
#  {'id': 6166102746857472,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T12:29:38.942025Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.425,
#   'max_temp': 20.925,
#   'the_temp': 20.735,
#   'wind_speed': 3.685687008226623,
#   'wind_direction': 310.6661282155967,
#   'air_pressure': 1012.5,
#   'humidity': 68,
#   'visibility': 12.615388630398472,
#   'predictability': 75},
#  {'id': 5281846424240128,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T09:29:38.063016Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.445,
#   'max_temp': 21.27,
#   'the_temp': 20.759999999999998,
#   'wind_speed': 3.3831434415599566,
#   'wind_direction': 307.9978606740761,
#   'air_pressure': 1012.5,
#   'humidity': 67,
#   'visibility': 11.950832140300644,
#   'predictability': 75},
#  {'id': 6165934974697472,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T06:29:38.188082Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.864999999999998,
#   'max_temp': 22.955,
#   'the_temp': 23.09,
#   'wind_speed': 3.2650830199024363,
#   'wind_direction': 307.7345209943367,
#   'air_pressure': 1013.0,
#   'humidity': 62,
#   'visibility': 12.941297820726954,
#   'predictability': 75},
#  {'id': 5314052773380096,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T03:29:38.077836Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.844999999999999,
#   'max_temp': 23.345,
#   'the_temp': 23.085,
#   'wind_speed': 3.437626586569103,
#   'wind_direction': 307.3905395389413,
#   'air_pressure': 1012.5,
#   'humidity': 63,
#   'visibility': 13.471638133301518,
#   'predictability': 75},
#  {'id': 5420806500777984,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-18T00:29:37.848180Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.48,
#   'max_temp': 24.29,
#   'the_temp': 23.21,
#   'wind_speed': 3.7764806744929618,
#   'wind_direction': 290.0,
#   'air_pressure': 1012.0,
#   'humidity': 60,
#   'visibility': 13.041959953869402,
#   'predictability': 73},
#  {'id': 6034350195867648,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-17T21:29:38.838727Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.48,
#   'max_temp': 24.29,
#   'the_temp': 23.59,
#   'wind_speed': 3.6944599078262943,
#   'wind_direction': 298.3780778653654,
#   'air_pressure': 1010.5,
#   'humidity': 60,
#   'visibility': 12.146564065855404,
#   'predictability': 75},
#  {'id': 5492408034787328,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T18:29:41.965740Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.765,
#   'max_temp': 22.625,
#   'the_temp': 22.54,
#   'wind_speed': 3.3230619386330496,
#   'wind_direction': 309.99847470611667,
#   'air_pressure': 1013.0,
#   'humidity': 65,
#   'visibility': 12.901840750019883,
#   'predictability': 75},
#  {'id': 4828190235164672,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T15:29:42.055016Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.765,
#   'max_temp': 22.625,
#   'the_temp': 22.435000000000002,
#   'wind_speed': 3.3230619386330496,
#   'wind_direction': 309.99847470611667,
#   'air_pressure': 1013.0,
#   'humidity': 66,
#   'visibility': 13.476609102839417,
#   'predictability': 75},
#  {'id': 5481795036381184,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T12:29:40.479368Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.745000000000001,
#   'max_temp': 22.965,
#   'the_temp': 22.625,
#   'wind_speed': 3.4518928572098946,
#   'wind_direction': 311.33387178440324,
#   'air_pressure': 1013.0,
#   'humidity': 63,
#   'visibility': 13.224643084387179,
#   'predictability': 75},
#  {'id': 4808211490144256,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-17T09:29:41.267969Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.55,
#   'max_temp': 23.31,
#   'the_temp': 22.595,
#   'wind_speed': 3.738210990543228,
#   'wind_direction': 326.5287173916311,
#   'air_pressure': 1013.5,
#   'humidity': 61,
#   'visibility': 12.605446691322676,
#   'predictability': 75},
#  {'id': 4745430644555776,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T06:29:41.346865Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.309999999999999,
#   'max_temp': 23.145,
#   'the_temp': 23.205,
#   'wind_speed': 3.5066467224899918,
#   'wind_direction': 323.9202374139645,
#   'air_pressure': 1013.5,
#   'humidity': 59,
#   'visibility': 12.826344150163049,
#   'predictability': 71},
#  {'id': 5665936256270336,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T03:29:41.267475Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.265,
#   'max_temp': 23.985,
#   'the_temp': 23.2,
#   'wind_speed': 3.1301543224899917,
#   'wind_direction': 315.0,
#   'air_pressure': 1013.5,
#   'humidity': 61,
#   'visibility': 13.83047999681858,
#   'predictability': 73},
#  {'id': 6450804183531520,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-17T00:29:40.654500Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.715,
#   'max_temp': 24.325,
#   'the_temp': 22.67,
#   'wind_speed': 3.4801932177152097,
#   'wind_direction': 284.0,
#   'air_pressure': 1013.5,
#   'humidity': 62,
#   'visibility': 12.908675833134495,
#   'predictability': 75},
#  {'id': 6192726309601280,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T21:29:40.612885Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.715,
#   'max_temp': 24.325,
#   'the_temp': 23.034999999999997,
#   'wind_speed': 3.52493181771521,
#   'wind_direction': 296.3952340365035,
#   'air_pressure': 1012.0,
#   'humidity': 60,
#   'visibility': 13.062465203213234,
#   'predictability': 75},
#  {'id': 6717817904693248,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T18:29:45.292134Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.08,
#   'max_temp': 24.17,
#   'the_temp': 23.775,
#   'wind_speed': 3.629774797998356,
#   'wind_direction': 286.57783312937227,
#   'air_pressure': 1013.5,
#   'humidity': 59,
#   'visibility': 12.953103873379463,
#   'predictability': 73},
#  {'id': 6282622391025664,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T15:29:44.543147Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.08,
#   'max_temp': 24.17,
#   'the_temp': 23.740000000000002,
#   'wind_speed': 3.6819698313316898,
#   'wind_direction': 286.57783312937227,
#   'air_pressure': 1013.0,
#   'humidity': 60,
#   'visibility': 13.768653563190965,
#   'predictability': 71},
#  {'id': 5448740968071168,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T12:29:43.717590Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.055,
#   'max_temp': 23.845,
#   'the_temp': 22.86,
#   'wind_speed': 3.4731890687929163,
#   'wind_direction': 294.27095968840945,
#   'air_pressure': 1012.5,
#   'humidity': 63,
#   'visibility': 13.328722759086933,
#   'predictability': 77},
#  {'id': 4787503775088640,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-16T09:29:43.072039Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.969999999999999,
#   'max_temp': 23.875,
#   'the_temp': 22.79,
#   'wind_speed': 3.759158668792916,
#   'wind_direction': 307.8915561164231,
#   'air_pressure': 1012.5,
#   'humidity': 63,
#   'visibility': 11.975686987990137,
#   'predictability': 77},
#  {'id': 6096300569264128,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T06:29:43.265141Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.85,
#   'max_temp': 24.28,
#   'the_temp': 23.1,
#   'wind_speed': 3.7450742131551737,
#   'wind_direction': 297.9668165243225,
#   'air_pressure': 1012.0,
#   'humidity': 61,
#   'visibility': 12.675040264853257,
#   'predictability': 75},
#  {'id': 5919543035691008,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T03:29:43.055793Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.965,
#   'max_temp': 23.79,
#   'the_temp': 23.255000000000003,
#   'wind_speed': 3.5427049131551738,
#   'wind_direction': 300.74522575347123,
#   'air_pressure': 1012.0,
#   'humidity': 63,
#   'visibility': 13.897588085580212,
#   'predictability': 75},
#  {'id': 4888432553754624,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-16T00:29:44.179349Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.715,
#   'max_temp': 21.015,
#   'the_temp': 20.065,
#   'wind_speed': 3.866646553882658,
#   'wind_direction': 306.13979750243465,
#   'air_pressure': 1010.0,
#   'humidity': 76,
#   'visibility': 13.623874075399666,
#   'predictability': 75},
#  {'id': 6000994439659520,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-15T21:29:42.971159Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.715,
#   'max_temp': 21.015,
#   'the_temp': 17.1,
#   'wind_speed': 4.334780680823988,
#   'wind_direction': 289.0,
#   'air_pressure': 1002.0,
#   'humidity': 83,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6483666857361408,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T18:29:46.542707Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.170000000000002,
#   'max_temp': 20.465,
#   'the_temp': 18.42,
#   'wind_speed': 4.030308796627694,
#   'wind_direction': 346.0,
#   'air_pressure': 1008.0,
#   'humidity': 78,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5982289555095552,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T15:29:47.339323Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.170000000000002,
#   'max_temp': 20.465,
#   'the_temp': 18.42,
#   'wind_speed': 4.030308796627694,
#   'wind_direction': 346.0,
#   'air_pressure': 1008.0,
#   'humidity': 78,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4505435287584768,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T12:29:47.547152Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.3,
#   'max_temp': 23.23,
#   'the_temp': 23.21,
#   'wind_speed': 4.170117314881095,
#   'wind_direction': 327.0,
#   'air_pressure': 1008.0,
#   'humidity': 67,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5184659904266240,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T09:29:47.792083Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.17,
#   'max_temp': 24.744999999999997,
#   'the_temp': 23.21,
#   'wind_speed': 4.050117314881094,
#   'wind_direction': 326.5,
#   'air_pressure': 1008.0,
#   'humidity': 60,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5209980615524352,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-15T06:29:47.889727Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.61,
#   'max_temp': 25.369999999999997,
#   'the_temp': 24.37,
#   'wind_speed': 4.1930326890956815,
#   'wind_direction': 320.5,
#   'air_pressure': 1011.0,
#   'humidity': 57,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5913899448664064,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T03:29:46.385115Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.565,
#   'max_temp': 25.11,
#   'the_temp': 24.37,
#   'wind_speed': 3.758032689095681,
#   'wind_direction': 338.0,
#   'air_pressure': 1011.0,
#   'humidity': 57,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5978459652227072,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-15T00:29:46.462514Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.115,
#   'max_temp': 24.64,
#   'the_temp': 23.8,
#   'wind_speed': 3.469095084705321,
#   'wind_direction': 15.999999999999995,
#   'air_pressure': 1008.0,
#   'humidity': 50,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 6040788351844352,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-14T21:29:46.479269Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.115,
#   'max_temp': 24.64,
#   'the_temp': 23.8,
#   'wind_speed': 3.469095084705321,
#   'wind_direction': 15.999999999999995,
#   'air_pressure': 1008.0,
#   'humidity': 50,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 5546936000053248,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-14T18:29:50.573289Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.844999999999999,
#   'max_temp': 23.275,
#   'the_temp': 21.16,
#   'wind_speed': 4.605901733874175,
#   'wind_direction': 346.5,
#   'air_pressure': 1011.0,
#   'humidity': 64,
#   'visibility': 9.529348604151753,
#   'predictability': 77},
#  {'id': 5112107471208448,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-14T15:30:06.980581Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.844999999999999,
#   'max_temp': 23.275,
#   'the_temp': 21.16,
#   'wind_speed': 4.605901733874175,
#   'wind_direction': 346.5,
#   'air_pressure': 1011.0,
#   'humidity': 64,
#   'visibility': 9.529348604151753,
#   'predictability': 77},
#  {'id': 4683193112330240,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T12:28:49.948758Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.82,
#   'max_temp': 24.8,
#   'the_temp': 24.02,
#   'wind_speed': 4.6152223017577345,
#   'wind_direction': 356.5,
#   'air_pressure': 1011.0,
#   'humidity': 62,
#   'visibility': 9.529348604151753,
#   'predictability': 77},
#  {'id': 6527141623627776,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T09:28:49.746457Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.0,
#   'max_temp': 24.455,
#   'the_temp': 24.02,
#   'wind_speed': 5.250222301757734,
#   'wind_direction': 2.999999999999988,
#   'air_pressure': 1011.0,
#   'humidity': 64,
#   'visibility': 9.651758729022509,
#   'predictability': 77},
#  {'id': 4983152957194240,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T06:28:49.218896Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.905,
#   'max_temp': 23.29,
#   'the_temp': 22.57,
#   'wind_speed': 5.060704088125348,
#   'wind_direction': 355.0,
#   'air_pressure': 1009.0,
#   'humidity': 65,
#   'visibility': 9.651758729022509,
#   'predictability': 77},
#  {'id': 6205194331226112,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T03:28:49.646224Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.995,
#   'max_temp': 23.75,
#   'the_temp': 22.57,
#   'wind_speed': 5.290704088125348,
#   'wind_direction': 358.5,
#   'air_pressure': 1009.0,
#   'humidity': 63,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6482354241536000,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T00:28:51.376018Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.219999999999999,
#   'max_temp': 24.14,
#   'the_temp': 22.75,
#   'wind_speed': 5.296917800047721,
#   'wind_direction': 1.9999999999999993,
#   'air_pressure': 1009.0,
#   'humidity': 54,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 6538574960787456,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T21:28:51.960596Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.219999999999999,
#   'max_temp': 24.14,
#   'the_temp': 22.75,
#   'wind_speed': 5.296917800047721,
#   'wind_direction': 1.9999999999999993,
#   'air_pressure': 1009.0,
#   'humidity': 54,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 5667761751588864,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T18:28:52.857300Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.64,
#   'max_temp': 24.21,
#   'the_temp': 23.11,
#   'wind_speed': 5.230222301757735,
#   'wind_direction': 351.5,
#   'air_pressure': 1017.0,
#   'humidity': 55,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 6074970922811392,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T15:28:52.787511Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.64,
#   'max_temp': 24.21,
#   'the_temp': 23.11,
#   'wind_speed': 5.230222301757735,
#   'wind_direction': 351.5,
#   'air_pressure': 1017.0,
#   'humidity': 55,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5568341815066624,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T12:28:52.974109Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.805,
#   'max_temp': 24.345,
#   'the_temp': 23.16,
#   'wind_speed': 5.295466276942655,
#   'wind_direction': 356.5,
#   'air_pressure': 1015.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5038612494155776,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T09:28:52.672721Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.049999999999999,
#   'max_temp': 24.134999999999998,
#   'the_temp': 23.16,
#   'wind_speed': 5.470466276942655,
#   'wind_direction': 9.499999999999998,
#   'air_pressure': 1015.0,
#   'humidity': 63,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6416168493514752,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-13T06:28:52.968890Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.37,
#   'max_temp': 23.560000000000002,
#   'the_temp': 21.89,
#   'wind_speed': 5.7842587290225085,
#   'wind_direction': 25.499999999999996,
#   'air_pressure': 1014.0,
#   'humidity': 58,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 4859397467537408,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-07-13T03:28:52.863944Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.79,
#   'max_temp': 23.51,
#   'the_temp': 21.89,
#   'wind_speed': 3.678517458045017,
#   'wind_direction': 40.0,
#   'air_pressure': 1014.0,
#   'humidity': 35,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 6360345226510336,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-13T00:28:51.971253Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.06,
#   'max_temp': 21.5,
#   'the_temp': 19.97,
#   'wind_speed': 4.219110395291498,
#   'wind_direction': 284.0,
#   'air_pressure': 1004.0,
#   'humidity': 40,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 5016182396551168,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-12T21:28:52.276977Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.06,
#   'max_temp': 21.5,
#   'the_temp': 19.97,
#   'wind_speed': 4.219110395291498,
#   'wind_direction': 284.0,
#   'air_pressure': 1004.0,
#   'humidity': 40,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 5271940921032704,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-12T18:28:55.556794Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 17.66,
#   'max_temp': 23.27,
#   'the_temp': 18.55,
#   'wind_speed': 1.6777022190408017,
#   'wind_direction': 14.999999999999998,
#   'air_pressure': 1005.0,
#   'humidity': 82,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5120773607915520,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-12T15:28:55.767568Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 17.66,
#   'max_temp': 23.27,
#   'the_temp': 18.55,
#   'wind_speed': 1.6777022190408017,
#   'wind_direction': 14.999999999999998,
#   'air_pressure': 1005.0,
#   'humidity': 82,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6677667845767168,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-12T12:28:56.353567Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 13.96,
#   'max_temp': 22.75,
#   'the_temp': 21.25,
#   'wind_speed': 2.895589755825976,
#   'wind_direction': 305.0,
#   'air_pressure': 1014.0,
#   'humidity': 42,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 6138189385302016,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-12T09:28:55.458437Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 13.96,
#   'max_temp': 22.75,
#   'the_temp': 21.25,
#   'wind_speed': 2.895589755825976,
#   'wind_direction': 305.0,
#   'air_pressure': 1014.0,
#   'humidity': 42,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 6017893491802112,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-12T06:28:56.068337Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.35,
#   'max_temp': 19.09,
#   'the_temp': 16.16,
#   'wind_speed': 4.026485325697924,
#   'wind_direction': 306.0,
#   'air_pressure': 1009.0,
#   'humidity': 74,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 5086167177363456,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-12T03:28:55.565714Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.35,
#   'max_temp': 19.09,
#   'the_temp': 16.16,
#   'wind_speed': 4.026485325697924,
#   'wind_direction': 306.0,
#   'air_pressure': 1009.0,
#   'humidity': 74,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 6477870966767616,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-12T00:28:57.379884Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.77,
#   'max_temp': 23.89,
#   'the_temp': 22.39,
#   'wind_speed': 2.8085977889127496,
#   'wind_direction': 17.000000000000004,
#   'air_pressure': 1011.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 4715301616746496,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-11T21:28:55.964456Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.77,
#   'max_temp': 23.89,
#   'the_temp': 22.39,
#   'wind_speed': 2.8085977889127496,
#   'wind_direction': 17.000000000000004,
#   'air_pressure': 1011.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 68}]

# %%
df = pd.read_json('https://www.metaweather.com/api/location/2122265/2020/07/20')
df.head()
# Out:
#    air_pressure applicable_date                      created  humidity  \
# 0        1011.5      2020-07-20  2020-07-20T18:29:31.885101Z        66
# 1        1011.5      2020-07-20  2020-07-20T15:29:31.460467Z        66
# 2        1013.0      2020-07-20  2020-07-20T12:29:32.565565Z        71
# 3        1013.0      2020-07-20  2020-07-20T09:29:32.257786Z        71
# 4        1013.0      2020-07-20  2020-07-20T06:29:32.073897Z        69
#
#                  id  max_temp  min_temp  predictability  the_temp  visibility  \
# 0  4919777191526400    24.020    16.795              75    23.005   12.808946
# 1  5843753002598400    24.020    16.795              73    22.950   12.808946
# 2  4695383806574592    23.920    16.725              73    21.940   12.808946
# 3  4806990276591616    22.765    16.840              73    21.900   12.501367
# 4  6202314589208576    21.955    15.115              75    20.640   11.168215
#
#   weather_state_abbr weather_state_name  wind_direction  \
# 0                 lr         Light Rain      300.697175
# 1                  s            Showers      300.697175
# 2                  s            Showers      313.666637
# 3                  s            Showers      317.329902
# 4                 lr         Light Rain      328.280489
#
#   wind_direction_compass  wind_speed
# 0                    WNW    2.833971
# 1                    WNW    2.833971
# 2                     NW    2.741180
# 3                     NW    2.541970
# 4                    NNW    2.356801

# %%
df['created'].min()
# Out:
# '2020-07-11T21:28:55.964456Z'

# %%
df['created'].max()
# Out:
# '2020-07-20T18:29:31.885101Z'

# %%
url = 'https://www.metaweather.com/api/location/search/?query=paris'

# %%
with req.urlopen(url3) as session:
    response = session.read().decode()
    data = json.loads(response)

data
# Out:
# [{'title': 'Paris',
#   'location_type': 'City',
#   'woeid': 615702,
#   'latt_long': '48.856930,2.341200'}]

# %%
url = 'https://www.metaweather.com/api/location/615702/2020/05/28'

# %%
with req.urlopen(url) as session:
    response = session.read().decode()
    s = json.loads(response)

s[:5]
# Out:
# [{'id': 6723109975490560,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T21:36:04.490586Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.969999999999999,
#   'max_temp': 21.925,
#   'the_temp': 21.810000000000002,
#   'wind_speed': 7.253747276680187,
#   'wind_direction': 45.33145222483384,
#   'air_pressure': 1028.0,
#   'humidity': 43,
#   'visibility': 15.078814722023383,
#   'predictability': 68},
#  {'id': 5582221102546944,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T18:36:05.696646Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.895,
#   'max_temp': 24.47,
#   'the_temp': 24.165,
#   'wind_speed': 7.1701854113072985,
#   'wind_direction': 41.66890844214983,
#   'air_pressure': 1028.5,
#   'humidity': 42,
#   'visibility': 15.078814722023383,
#   'predictability': 68},
#  {'id': 4875719383449600,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T15:36:05.294001Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.895,
#   'max_temp': 24.47,
#   'the_temp': 24.165,
#   'wind_speed': 7.1701854113072985,
#   'wind_direction': 41.66890844214983,
#   'air_pressure': 1028.5,
#   'humidity': 42,
#   'visibility': 15.078814722023383,
#   'predictability': 68},
#  {'id': 5781794072821760,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T12:36:04.965983Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.865,
#   'max_temp': 23.555,
#   'the_temp': 22.34,
#   'wind_speed': 7.230251293223574,
#   'wind_direction': 42.6700978815524,
#   'air_pressure': 1030.0,
#   'humidity': 48,
#   'visibility': 15.078814722023383,
#   'predictability': 68},
#  {'id': 5252630563520512,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T09:36:04.743683Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.93,
#   'max_temp': 23.0,
#   'the_temp': 22.369999999999997,
#   'wind_speed': 7.199635793223574,
#   'wind_direction': 43.33499086401919,
#   'air_pressure': 1030.0,
#   'humidity': 47,
#   'visibility': 14.516473793048595,
#   'predictability': 68}]

# %%
with open('file.json', 'w') as file:
    json.dump(s, file, indent=4)

# %%
with open('file.json', 'r') as file:
    s = json.load(file)
s
# Out:
# [{'id': 6723109975490560,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T21:36:04.490586Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.969999999999999,
#   'max_temp': 21.925,
#   'the_temp': 21.810000000000002,
#   'wind_speed': 7.253747276680187,
#   'wind_direction': 45.33145222483384,
#   'air_pressure': 1028.0,
#   'humidity': 43,
#   'visibility': 15.078814722023383,
#   'predictability': 68},
#  {'id': 5582221102546944,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T18:36:05.696646Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.895,
#   'max_temp': 24.47,
#   'the_temp': 24.165,
#   'wind_speed': 7.1701854113072985,
#   'wind_direction': 41.66890844214983,
#   'air_pressure': 1028.5,
#   'humidity': 42,
#   'visibility': 15.078814722023383,
#   'predictability': 68},
#  {'id': 4875719383449600,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T15:36:05.294001Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.895,
#   'max_temp': 24.47,
#   'the_temp': 24.165,
#   'wind_speed': 7.1701854113072985,
#   'wind_direction': 41.66890844214983,
#   'air_pressure': 1028.5,
#   'humidity': 42,
#   'visibility': 15.078814722023383,
#   'predictability': 68},
#  {'id': 5781794072821760,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T12:36:04.965983Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.865,
#   'max_temp': 23.555,
#   'the_temp': 22.34,
#   'wind_speed': 7.230251293223574,
#   'wind_direction': 42.6700978815524,
#   'air_pressure': 1030.0,
#   'humidity': 48,
#   'visibility': 15.078814722023383,
#   'predictability': 68},
#  {'id': 5252630563520512,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T09:36:04.743683Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.93,
#   'max_temp': 23.0,
#   'the_temp': 22.369999999999997,
#   'wind_speed': 7.199635793223574,
#   'wind_direction': 43.33499086401919,
#   'air_pressure': 1030.0,
#   'humidity': 47,
#   'visibility': 14.516473793048595,
#   'predictability': 68},
#  {'id': 5289841942069248,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T06:36:05.727953Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.26,
#   'max_temp': 23.045,
#   'the_temp': 22.945,
#   'wind_speed': 7.328880812447308,
#   'wind_direction': 43.33499086401919,
#   'air_pressure': 1030.0,
#   'humidity': 41,
#   'visibility': 14.767818440308597,
#   'predictability': 68},
#  {'id': 4757113928679424,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T03:36:04.139803Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.265,
#   'max_temp': 23.725,
#   'the_temp': 22.939999999999998,
#   'wind_speed': 7.281424379113974,
#   'wind_direction': 43.66772105683653,
#   'air_pressure': 1030.0,
#   'humidity': 41,
#   'visibility': 14.791741231209734,
#   'predictability': 68},
#  {'id': 6042184316878848,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-28T00:36:05.444888Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.35,
#   'max_temp': 23.674999999999997,
#   'the_temp': 23.64,
#   'wind_speed': 6.477372300524935,
#   'wind_direction': 44.66717930710006,
#   'air_pressure': 1032.0,
#   'humidity': 40,
#   'visibility': 15.262740594925633,
#   'predictability': 68},
#  {'id': 6200513991278592,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-27T21:36:07.563939Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.35,
#   'max_temp': 23.674999999999997,
#   'the_temp': 22.945,
#   'wind_speed': 7.245384933858268,
#   'wind_direction': 44.66717930710006,
#   'air_pressure': 1030.0,
#   'humidity': 40,
#   'visibility': 14.211380537660064,
#   'predictability': 68},
#  {'id': 6472988142600192,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-27T18:36:08.666568Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.085,
#   'max_temp': 23.990000000000002,
#   'the_temp': 23.060000000000002,
#   'wind_speed': 7.057525806686286,
#   'wind_direction': 44.667009421867306,
#   'air_pressure': 1030.0,
#   'humidity': 42,
#   'visibility': 14.277245884037223,
#   'predictability': 68},
#  {'id': 6163146769170432,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-27T15:36:07.623915Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.085,
#   'max_temp': 23.990000000000002,
#   'the_temp': 23.060000000000002,
#   'wind_speed': 7.027700073352951,
#   'wind_direction': 44.667009421867306,
#   'air_pressure': 1030.0,
#   'humidity': 42,
#   'visibility': 14.325402151435616,
#   'predictability': 68},
#  {'id': 6149668692033536,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-27T12:36:07.936584Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.094999999999999,
#   'max_temp': 23.905,
#   'the_temp': 23.005000000000003,
#   'wind_speed': 7.031842547967867,
#   'wind_direction': 46.330033829667855,
#   'air_pressure': 1030.0,
#   'humidity': 42,
#   'visibility': 14.325402151435616,
#   'predictability': 68},
#  {'id': 5915584854228992,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-27T09:36:08.137159Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.205,
#   'max_temp': 23.725,
#   'the_temp': 23.07,
#   'wind_speed': 6.916836981301202,
#   'wind_direction': 46.330033829667855,
#   'air_pressure': 1030.0,
#   'humidity': 42,
#   'visibility': 13.59932991330629,
#   'predictability': 68},
#  {'id': 5419338293051392,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-27T06:36:07.238749Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.295000000000002,
#   'max_temp': 23.925,
#   'the_temp': 23.17,
#   'wind_speed': 7.04401055348233,
#   'wind_direction': 46.330033829667855,
#   'air_pressure': 1029.5,
#   'humidity': 42,
#   'visibility': 14.569601029984888,
#   'predictability': 68},
#  {'id': 4821020156362752,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-27T03:36:07.042970Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.375,
#   'max_temp': 24.075000000000003,
#   'the_temp': 23.174999999999997,
#   'wind_speed': 6.954359086815663,
#   'wind_direction': 45.99714451257869,
#   'air_pressure': 1029.5,
#   'humidity': 42,
#   'visibility': 14.705059949892627,
#   'predictability': 68},
#  {'id': 4860306490654720,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-27T00:36:07.833039Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.524999999999999,
#   'max_temp': 24.105,
#   'the_temp': 23.96,
#   'wind_speed': 6.330918440019619,
#   'wind_direction': 44.33417736024788,
#   'air_pressure': 1032.0,
#   'humidity': 41,
#   'visibility': 15.112368766404199,
#   'predictability': 68},
#  {'id': 5037060769447936,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-26T21:36:10.402115Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.524999999999999,
#   'max_temp': 24.105,
#   'the_temp': 23.285,
#   'wind_speed': 6.860325206686286,
#   'wind_direction': 44.33417736024788,
#   'air_pressure': 1030.0,
#   'humidity': 42,
#   'visibility': 14.10761154855643,
#   'predictability': 68},
#  {'id': 6705071985262592,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-26T18:36:11.055655Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.54,
#   'max_temp': 24.384999999999998,
#   'the_temp': 23.555,
#   'wind_speed': 6.924657044640632,
#   'wind_direction': 45.332990578132694,
#   'air_pressure': 1029.5,
#   'humidity': 42,
#   'visibility': 14.162602899069434,
#   'predictability': 70},
#  {'id': 6667810811936768,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-26T15:36:10.815192Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.54,
#   'max_temp': 24.384999999999998,
#   'the_temp': 23.555,
#   'wind_speed': 6.887374877973966,
#   'wind_direction': 45.332990578132694,
#   'air_pressure': 1029.5,
#   'humidity': 42,
#   'visibility': 14.22442933269705,
#   'predictability': 70},
#  {'id': 6744567514660864,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-26T12:36:11.710995Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.350000000000001,
#   'max_temp': 24.25,
#   'the_temp': 23.255000000000003,
#   'wind_speed': 6.9901082274503565,
#   'wind_direction': 45.332990578132694,
#   'air_pressure': 1029.5,
#   'humidity': 43,
#   'visibility': 13.976502226994352,
#   'predictability': 68},
#  {'id': 4966362722074624,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-26T09:36:10.860757Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.93,
#   'max_temp': 23.924999999999997,
#   'the_temp': 23.255000000000003,
#   'wind_speed': 7.114928394117023,
#   'wind_direction': 46.332753728080995,
#   'air_pressure': 1029.5,
#   'humidity': 45,
#   'visibility': 13.356063091545375,
#   'predictability': 68},
#  {'id': 4854144907083776,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-26T06:36:10.727247Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.825,
#   'max_temp': 23.91,
#   'the_temp': 22.895,
#   'wind_speed': 7.464966450401654,
#   'wind_direction': 46.998474706116646,
#   'air_pressure': 1029.5,
#   'humidity': 46,
#   'visibility': 14.703817207508152,
#   'predictability': 68},
#  {'id': 6056201546629120,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-26T03:36:10.227151Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.795,
#   'max_temp': 23.905,
#   'the_temp': 22.939999999999998,
#   'wind_speed': 7.314525217068321,
#   'wind_direction': 46.66500913598081,
#   'air_pressure': 1029.5,
#   'humidity': 45,
#   'visibility': 14.999279209417004,
#   'predictability': 68},
#  {'id': 6505120453885952,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-26T00:36:10.409028Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.68,
#   'max_temp': 23.925,
#   'the_temp': 23.865000000000002,
#   'wind_speed': 6.466562949508205,
#   'wind_direction': 46.66500913598081,
#   'air_pressure': 1031.0,
#   'humidity': 44,
#   'visibility': 14.993997554282988,
#   'predictability': 70},
#  {'id': 5156380614852608,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-25T21:36:14.038234Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.68,
#   'max_temp': 23.925,
#   'the_temp': 23.15,
#   'wind_speed': 7.279314182841539,
#   'wind_direction': 46.66500913598081,
#   'air_pressure': 1029.5,
#   'humidity': 45,
#   'visibility': 13.763993279249185,
#   'predictability': 70},
#  {'id': 6373970003623936,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-25T18:36:14.408100Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.815000000000001,
#   'max_temp': 22.435000000000002,
#   'the_temp': 22.665,
#   'wind_speed': 7.697188721289006,
#   'wind_direction': 47.66568781397159,
#   'air_pressure': 1029.0,
#   'humidity': 44,
#   'visibility': 14.792362602401973,
#   'predictability': 68},
#  {'id': 6483921166401536,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-25T15:36:13.607912Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.815000000000001,
#   'max_temp': 22.435000000000002,
#   'the_temp': 22.725,
#   'wind_speed': 7.607711521289006,
#   'wind_direction': 47.66568781397159,
#   'air_pressure': 1029.0,
#   'humidity': 44,
#   'visibility': 15.188176051857154,
#   'predictability': 68},
#  {'id': 5578784457621504,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-25T12:36:14.059214Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.185,
#   'max_temp': 22.725,
#   'the_temp': 23.075,
#   'wind_speed': 7.523619307579735,
#   'wind_direction': 49.65939834253432,
#   'air_pressure': 1028.5,
#   'humidity': 45,
#   'visibility': 14.416743716694503,
#   'predictability': 70},
#  {'id': 4602169158270976,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-25T09:36:13.709177Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.925,
#   'max_temp': 24.13,
#   'the_temp': 23.134999999999998,
#   'wind_speed': 7.037034207579733,
#   'wind_direction': 49.993884838190134,
#   'air_pressure': 1028.5,
#   'humidity': 46,
#   'visibility': 14.13557325220711,
#   'predictability': 70},
#  {'id': 6223745553268736,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-25T06:36:12.939997Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.11,
#   'max_temp': 25.064999999999998,
#   'the_temp': 24.35,
#   'wind_speed': 6.781443712601077,
#   'wind_direction': 48.99755785394186,
#   'air_pressure': 1028.0,
#   'humidity': 45,
#   'visibility': 15.207438558816511,
#   'predictability': 70},
#  {'id': 6721734126338048,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-25T03:36:13.575923Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.26,
#   'max_temp': 24.994999999999997,
#   'the_temp': 24.4,
#   'wind_speed': 6.740212712601076,
#   'wind_direction': 48.329563055302316,
#   'air_pressure': 1028.0,
#   'humidity': 45,
#   'visibility': 15.98601666268989,
#   'predictability': 70},
#  {'id': 5877748541161472,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-25T00:36:14.838811Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.49,
#   'max_temp': 24.85,
#   'the_temp': 24.424999999999997,
#   'wind_speed': 6.450240538232721,
#   'wind_direction': 46.99918694391275,
#   'air_pressure': 1030.0,
#   'humidity': 43,
#   'visibility': 15.06545524139028,
#   'predictability': 68},
#  {'id': 5428587656118272,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-24T21:36:16.339203Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.49,
#   'max_temp': 24.85,
#   'the_temp': 23.965,
#   'wind_speed': 6.837975071566055,
#   'wind_direction': 46.99918694391275,
#   'air_pressure': 1028.0,
#   'humidity': 44,
#   'visibility': 14.749487990137597,
#   'predictability': 68},
#  {'id': 4724533984493568,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-24T18:36:16.649017Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.665,
#   'max_temp': 24.03,
#   'the_temp': 23.84,
#   'wind_speed': 6.895520829637583,
#   'wind_direction': 49.664159623118564,
#   'air_pressure': 1028.5,
#   'humidity': 45,
#   'visibility': 15.51532798457011,
#   'predictability': 68},
#  {'id': 6702115101605888,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-05-24T15:36:17.647650Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.665,
#   'max_temp': 24.03,
#   'the_temp': 23.83,
#   'wind_speed': 6.828412929637584,
#   'wind_direction': 57.16101482384726,
#   'air_pressure': 1028.5,
#   'humidity': 45,
#   'visibility': 16.304469398711525,
#   'predictability': 68},
#  {'id': 6207703229661184,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-24T12:36:16.424975Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.975000000000001,
#   'max_temp': 24.92,
#   'the_temp': 24.33,
#   'wind_speed': 6.7298220547761085,
#   'wind_direction': 49.33166776031588,
#   'air_pressure': 1028.0,
#   'humidity': 44,
#   'visibility': 15.048056848007635,
#   'predictability': 68},
#  {'id': 5757410805284864,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-24T09:36:18.432023Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.09,
#   'max_temp': 24.735,
#   'the_temp': 23.905,
#   'wind_speed': 6.660263288109442,
#   'wind_direction': 47.99572330791149,
#   'air_pressure': 1028.0,
#   'humidity': 44,
#   'visibility': 14.776828322596039,
#   'predictability': 68},
#  {'id': 5363072812187648,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-24T06:36:16.692890Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.059999999999999,
#   'max_temp': 24.39,
#   'the_temp': 23.66,
#   'wind_speed': 6.9605921733529525,
#   'wind_direction': 47.663515435769895,
#   'air_pressure': 1029.0,
#   'humidity': 43,
#   'visibility': 15.581814702139505,
#   'predictability': 68},
#  {'id': 6016877916585984,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-24T03:36:16.676387Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.695,
#   'max_temp': 24.354999999999997,
#   'the_temp': 23.325000000000003,
#   'wind_speed': 7.101997440019619,
#   'wind_direction': 45.99714451257869,
#   'air_pressure': 1029.0,
#   'humidity': 43,
#   'visibility': 16.475657162172908,
#   'predictability': 68},
#  {'id': 5606074814038016,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-24T00:36:17.425413Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.879999999999999,
#   'max_temp': 23.72,
#   'the_temp': 23.61,
#   'wind_speed': 6.114019970919165,
#   'wind_direction': 34.52073567458125,
#   'air_pressure': 1031.0,
#   'humidity': 44,
#   'visibility': 15.078504036427265,
#   'predictability': 68},
#  {'id': 5681012396785664,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-23T21:36:19.100758Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.879999999999999,
#   'max_temp': 23.72,
#   'the_temp': 21.84,
#   'wind_speed': 6.0505126063787475,
#   'wind_direction': 40.5,
#   'air_pressure': 1029.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 5432608601145344,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-23T18:36:19.994801Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.785,
#   'max_temp': 25.384999999999998,
#   'the_temp': 23.82,
#   'wind_speed': 5.455802910999761,
#   'wind_direction': 52.50000000000001,
#   'air_pressure': 1026.0,
#   'humidity': 47,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 6193239658856448,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-23T15:36:19.519993Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.785,
#   'max_temp': 25.384999999999998,
#   'the_temp': 23.82,
#   'wind_speed': 5.455802910999761,
#   'wind_direction': 52.50000000000001,
#   'air_pressure': 1026.0,
#   'humidity': 47,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 4564126032461824,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-23T12:36:19.831963Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.11,
#   'max_temp': 24.450000000000003,
#   'the_temp': 22.42,
#   'wind_speed': 5.375024656008907,
#   'wind_direction': 47.0,
#   'air_pressure': 1028.0,
#   'humidity': 48,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 4699994621739008,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-23T09:36:19.172204Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.265,
#   'max_temp': 23.925,
#   'the_temp': 22.42,
#   'wind_speed': 5.600024656008908,
#   'wind_direction': 46.5,
#   'air_pressure': 1028.0,
#   'humidity': 45,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 5644156896542720,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-23T06:36:20.689124Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.504999999999999,
#   'max_temp': 24.11,
#   'the_temp': 21.92,
#   'wind_speed': 5.6310932156207745,
#   'wind_direction': 48.50000000000001,
#   'air_pressure': 1029.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 6035583036030976,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-23T03:36:21.613875Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.05,
#   'max_temp': 23.799999999999997,
#   'the_temp': 21.92,
#   'wind_speed': 5.466093215620775,
#   'wind_direction': 51.50000000000001,
#   'air_pressure': 1029.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 5976720559570944,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-05-23T00:36:19.602302Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.815,
#   'max_temp': 23.93,
#   'the_temp': 22.47,
#   'wind_speed': 5.497161775232642,
#   'wind_direction': 58.00000000000001,
#   'air_pressure': 1029.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 5712597250736128,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-05-22T21:36:22.512809Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.815,
#   'max_temp': 23.93,
#   'the_temp': 22.47,
#   'wind_speed': 5.497161775232642,
#   'wind_direction': 58.00000000000001,
#   'air_pressure': 1029.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 6431697803411456,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-05-22T18:36:23.089844Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.505,
#   'max_temp': 25.345,
#   'the_temp': 25.42,
#   'wind_speed': 5.1729801956573604,
#   'wind_direction': 73.0,
#   'air_pressure': 1025.0,
#   'humidity': 42,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5492343006298112,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-05-22T15:36:22.076628Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.505,
#   'max_temp': 25.345,
#   'the_temp': 25.42,
#   'wind_speed': 5.1729801956573604,
#   'wind_direction': 73.0,
#   'air_pressure': 1025.0,
#   'humidity': 42,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5848053221163008,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-22T12:36:23.774987Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.025,
#   'max_temp': 24.77,
#   'the_temp': 24.59,
#   'wind_speed': 4.943072854529547,
#   'wind_direction': 41.49999999999999,
#   'air_pressure': 1027.0,
#   'humidity': 41,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 6005812872871936,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-22T09:36:23.207901Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 15.495000000000001,
#   'max_temp': 24.79,
#   'the_temp': 24.59,
#   'wind_speed': 4.6930728545295475,
#   'wind_direction': 37.49999999999999,
#   'air_pressure': 1027.0,
#   'humidity': 40,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 6132252280881152,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-22T06:36:23.492704Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.844999999999999,
#   'max_temp': 24.96,
#   'the_temp': 24.26,
#   'wind_speed': 4.907445915851428,
#   'wind_direction': 56.0,
#   'air_pressure': 1027.0,
#   'humidity': 40,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 5008698768359424,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-05-22T03:36:22.362940Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.399999999999999,
#   'max_temp': 24.494999999999997,
#   'the_temp': 24.26,
#   'wind_speed': 5.407445915851428,
#   'wind_direction': 50.5,
#   'air_pressure': 1027.0,
#   'humidity': 38,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 6381290053959680,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-05-22T00:36:22.339759Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.184999999999999,
#   'max_temp': 22.564999999999998,
#   'the_temp': 19.96,
#   'wind_speed': 5.814444046766881,
#   'wind_direction': 31.000000000000007,
#   'air_pressure': 1031.0,
#   'humidity': 37,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 5549717947678720,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-05-21T21:36:26.722499Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.184999999999999,
#   'max_temp': 22.564999999999998,
#   'the_temp': 19.96,
#   'wind_speed': 5.814444046766881,
#   'wind_direction': 31.000000000000007,
#   'air_pressure': 1031.0,
#   'humidity': 37,
#   'visibility': 9.999726596675416,
#   'predictability': 68},
#  {'id': 6469503900712960,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'N',
#   'created': '2020-05-21T18:36:26.203345Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.77,
#   'max_temp': 22.285,
#   'the_temp': 19.41,
#   'wind_speed': 4.978322993716694,
#   'wind_direction': 357.0,
#   'air_pressure': 1029.0,
#   'humidity': 41,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 6334046940430336,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'N',
#   'created': '2020-05-21T15:36:26.233351Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.77,
#   'max_temp': 22.285,
#   'the_temp': 19.41,
#   'wind_speed': 4.978322993716694,
#   'wind_direction': 357.0,
#   'air_pressure': 1029.0,
#   'humidity': 41,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 6133640813608960,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-05-21T12:36:25.544658Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.024999999999999,
#   'max_temp': 22.5,
#   'the_temp': 20.07,
#   'wind_speed': 5.037353256979241,
#   'wind_direction': 346.0,
#   'air_pressure': 1027.0,
#   'humidity': 41,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5679306372022272,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-05-21T09:36:25.434017Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.76,
#   'max_temp': 23.055,
#   'the_temp': 20.07,
#   'wind_speed': 4.067353256979241,
#   'wind_direction': 340.5,
#   'air_pressure': 1027.0,
#   'humidity': 42,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5732023656251392,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-05-21T06:36:25.429869Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 16.325,
#   'max_temp': 25.395,
#   'the_temp': 24.92,
#   'wind_speed': 3.995895569871948,
#   'wind_direction': 315.0,
#   'air_pressure': 1020.0,
#   'humidity': 45,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6271871467126784,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-05-21T03:36:26.968218Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 16.9,
#   'max_temp': 25.31,
#   'the_temp': 24.92,
#   'wind_speed': 2.2617911397438957,
#   'wind_direction': 290.0,
#   'air_pressure': 1020.0,
#   'humidity': 48,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6633380609261568,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-05-21T00:36:26.349173Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.96,
#   'max_temp': 24.92,
#   'the_temp': 24.92,
#   'wind_speed': 2.473057345104589,
#   'wind_direction': 307.0,
#   'air_pressure': 1018.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5584220946694144,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-05-20T21:36:28.346685Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 14.96,
#   'max_temp': 24.92,
#   'the_temp': 24.92,
#   'wind_speed': 2.473057345104589,
#   'wind_direction': 307.0,
#   'air_pressure': 1018.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 4923229841915904,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-05-20T18:36:28.838741Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 12.25,
#   'max_temp': 20.32,
#   'the_temp': 20.32,
#   'wind_speed': 3.585311779209417,
#   'wind_direction': 340.0,
#   'air_pressure': 1024.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5966515046187008,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-05-20T15:36:29.945429Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 12.25,
#   'max_temp': 20.32,
#   'the_temp': 20.32,
#   'wind_speed': 3.585311779209417,
#   'wind_direction': 340.0,
#   'air_pressure': 1024.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5687098029899776,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'N',
#   'created': '2020-05-20T12:36:28.268133Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.76,
#   'max_temp': 21.57,
#   'the_temp': 21.21,
#   'wind_speed': 3.1254970969537896,
#   'wind_direction': 359.0,
#   'air_pressure': 1026.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 6564044318179328,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'N',
#   'created': '2020-05-20T09:36:28.742969Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.76,
#   'max_temp': 21.57,
#   'the_temp': 21.21,
#   'wind_speed': 3.1254970969537896,
#   'wind_direction': 359.0,
#   'air_pressure': 1026.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 6519098827603968,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-05-20T06:36:28.439998Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 11.26,
#   'max_temp': 19.58,
#   'the_temp': 19.58,
#   'wind_speed': 3.8773562395609638,
#   'wind_direction': 335.0,
#   'air_pressure': 1024.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 5622980962942976,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-05-20T03:36:29.023744Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 11.26,
#   'max_temp': 19.58,
#   'the_temp': 19.58,
#   'wind_speed': 3.8773562395609638,
#   'wind_direction': 335.0,
#   'air_pressure': 1024.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 6540366297694208,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SSW',
#   'created': '2020-05-20T00:36:28.339328Z',
#   'applicable_date': '2020-05-28',
#   'min_temp': 13.57,
#   'max_temp': 31.07,
#   'the_temp': 30.55,
#   'wind_speed': 3.5542432195975504,
#   'wind_direction': 206.0,
#   'air_pressure': 1014.0,
#   'humidity': 43,
#   'visibility': None,
#   'predictability': 77}]

# %%
df = pd.read_json('file.json')
df.head()
# Out:
#    air_pressure applicable_date                      created  humidity  \
# 0        1028.0      2020-05-28  2020-05-28T21:36:04.490586Z        43
# 1        1028.5      2020-05-28  2020-05-28T18:36:05.696646Z        42
# 2        1028.5      2020-05-28  2020-05-28T15:36:05.294001Z        42
# 3        1030.0      2020-05-28  2020-05-28T12:36:04.965983Z        48
# 4        1030.0      2020-05-28  2020-05-28T09:36:04.743683Z        47
#
#                  id  max_temp  min_temp  predictability  the_temp  visibility  \
# 0  6723109975490560    21.925    14.970              68    21.810   15.078815
# 1  5582221102546944    24.470    13.895              68    24.165   15.078815
# 2  4875719383449600    24.470    13.895              68    24.165   15.078815
# 3  5781794072821760    23.555    13.865              68    22.340   15.078815
# 4  5252630563520512    23.000    13.930              68    22.370   14.516474
#
#   weather_state_abbr weather_state_name  wind_direction  \
# 0                  c              Clear       45.331452
# 1                  c              Clear       41.668908
# 2                  c              Clear       41.668908
# 3                  c              Clear       42.670098
# 4                  c              Clear       43.334991
#
#   wind_direction_compass  wind_speed
# 0                     NE    7.253747
# 1                     NE    7.170185
# 2                     NE    7.170185
# 3                     NE    7.230251
# 4                     NE    7.199636

# %%
import psycopg2
import sqlalchemy

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['keywords', 'links', 'ratings', 'exploratory', 'course_purchases', 'joi']

# %%
df = pd.read_sql('select * from course_purchases', connect).iloc[1:,:]
df.head()
# Out:
#                                 user_id                             course_id  \
# 1  ed5da480-57a2-489c-8e68-512155ab9892  fc082ec6-7721-4419-916b-06e4b560b50e
# 2  7ba07e70-f76a-4bbc-9b5d-34265f4f7638  66583e42-987a-4c38-b168-e5ee4772a627
# 3  7ba07e70-f76a-4bbc-9b5d-34265f4f7638  b45874ec-57c7-41e7-a38c-580330a23f50
# 4  8b1752da-599d-413a-a2e9-bc75387b2be9  2d98baac-eb91-4285-99e1-bee66018cd25
# 5  3e3b7b84-65f0-4152-815a-730bec31bb9d  83982097-8179-4ba2-affa-f8aef42fc070
#
#   purchase_date purchase_place
# 1    2019-03-22   Екатеринбург
# 2    2018-10-28     Курганинск
# 3    2019-04-06    Владивосток
# 4    2019-03-23    Владивосток
# 5    2019-03-25        Катайск

# %%
df.groupby('purchase_place')['course_id'].count()
# Out:
# purchase_place
# Алдан                         1
# Александровск-Сахалинский     1
# Ангарск                       1
# Анива                         1
# Арзамас                       1
# Аршан (Бурят.)                1
# Асбест                        1
# Аша                           1
# Белогорск (Амур.)             1
# Биробиджан                    1
# Верхний Баскунчак             1
# Владивосток                  25
# Волхов                        1
# Гаврилов-Ям                   1
# Диксон                        1
# Екатеринбург                 15
# Зеленогорск (Ленин.)          1
# Златоуст                      1
# Карабудахкент                 1
# Катайск                       1
# Качканар                      1
# Колпашево                     2
# Костомукша                    1
# Крымск                        1
# Курганинск                    1
# Минусинск                     1
# Москва                       30
# Нефтеюганск                   1
# Орел                          1
# Орск                          1
# Павловский Посад              1
# Пермь                         1
# Печора                        1
# Рославль                      1
# Санкт-Петербург              19
# Саратов                       1
# Сасово                        1
# Североуральск                 1
# Сосногорск                    1
# Сочи                         20
# Тольятти                      1
# Троицк (Моск.)                1
# Тымовское                     1
# Усть-Кулом                    1
# Хужир                         1
# Шатки                         1
# Шенкурск                      1
# Южно-Курильск                 1
# Name: course_id, dtype: int64

# %%
df_1 = pd.read_sql('select purchase_place, count(course_id) from course_purchases group by purchase_place', connect)
df_1
# Out:
#                purchase_place  count
# 0                      Асбест      1
# 1   Александровск-Сахалинский      1
# 2                  Костомукша      1
# 3                        Орел      1
# 4                     Саратов      1
# 5        Зеленогорск (Ленин.)      1
# 6                   Минусинск      1
# 7                      Печора      1
# 8                     Катайск      1
# 9            Павловский Посад      1
# 10                 Усть-Кулом      1
# 11             purchase_place      1
# 12                   Качканар      1
# 13                       Орск      1
# 14                  Тымовское      1
# 15                      Шатки      1
# 16                      Анива      1
# 17              Североуральск      1
# 18                     Крымск      1
# 19                   Рославль      1
# 20               Екатеринбург     15
# 21              Южно-Курильск      1
# 22                 Биробиджан      1
# 23                      Пермь      1
# 24                     Волхов      1
# 25                   Златоуст      1
# 26                     Сасово      1
# 27                     Москва     30
# 28                       Сочи     20
# 29                     Диксон      1
# 30            Санкт-Петербург     19
# 31                Гаврилов-Ям      1
# 32                    Ангарск      1
# 33                      Хужир      1
# 34                 Сосногорск      1
# 35                Нефтеюганск      1
# 36              Карабудахкент      1
# 37                   Шенкурск      1
# 38          Верхний Баскунчак      1
# 39                 Курганинск      1
# 40             Аршан (Бурят.)      1
# 41             Троицк (Моск.)      1
# 42                   Тольятти      1
# 43          Белогорск (Амур.)      1
# 44                  Колпашево      2
# 45                      Алдан      1
# 46                    Арзамас      1
# 47                Владивосток     25
# 48                        Аша      1
