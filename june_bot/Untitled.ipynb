# %%
BOT_CONFIG = {
    'heroes': {
        'athalia': ['Аталия'],
        'twins': ['Близнецы', 'Твины', 'Илия и Лэйла', 'Илия и Лейла', 'Близняшки'],
        'orthros': ['Ортрус'],
        'talene': ['Талена', 'Феникс'],
        'wu_kong': ['Укун', 'Обезьяна', 'Макака', 'Вуконг', 'У-кун'],
        'floha': ['Флора', 'Муха'],
        'zaphrael': ['Зафраэль', 'Зефир', 'Зефирка'],
        'ezizh': ['Эзиж', 'Эжиж'],
        'mehira': ['Мегира', 'Суккуб', 'Сукуб'],
        'zolrath': ['Золрат', 'Золтран'],
        'khazard': ['Хазард', 'Ледяной маг', 'Морозный маг']
        'mezoth': ['Мезот'],
        'lucretia': ['Лукреция', 'Лакрица', 'Лакричка', 'Феминистка'],
        'estrilda': ['Эстрильда'],
        'belinda': ['Белинда', 'Белка', 'Белая магичка'],
        'raine': ['Райна', 'Раина'],
        'fawkes': ['Фокс', 'Фоукс', 'Гробовщик', 'C гробом'],
        'lucius': ['Люций', 'Люц', 'Люциус'],
        'thane': ['Тейн', 'Тэйн', 'Однорукий'],
        'hendrik': ['Хендрик', 'Хэндрик', 'Мужик с дверьми', 'Двери'],
        'rowan': ['Рован', 'Бомж', 'C уткой'],
        'gwyneth': ['Гвинет', 'Баба с луком', 'Девчонка с луком', 'Телка с луком'],
        'rosaline': ['Розалина', 'Роза', 'Горничная', 'Уборщица'],
        'cecilia'['Сесилия'],
        'rigby': ['Ригби', 'Мужик с бочкой', 'Алкаш', 'Чувак с бочкой'],
        'oscar': ['Оскар', 'Дворецкий'],
        'brutus': ['Брутус', 'Брут', 'Лев', 'Лев с мечом'],
        'khasos': ['Хасос'],
        'vurk': ['Вурк', 'Крыса', 'Крысюк'],
        'numisu': ['Нумису', 'Шаман', 'Шаман с тотемами'],
        'skreg': ['Скрег', 'Скрэг', 'Носорог'],
        'warek': ['Варек', 'Медведь'],
        'antandra': ['Антандра', 'Андатра', 'Ондатра'],
        'safiya': ['Сафия', 'Сфинкс'],
        'satrana': ['Сатрана'],
        'tidus': ['Тайдус', 'Волк'],
        'drez': ['Дрез', 'Дрэз'],
        'skriath': ['Скриат', 'Ворон', 'Ворона', 'Курица'],
        'anoki': ['Аноки', 'Бык'],
        'nemora': ['Немора', 'Овечка', 'Овца', 'Барашек'],
        'kaz': ['Каз'],
        'lyca': ['Лика'],
        'tasi': ['Тази', 'Таз', 'Тазик', 'Фея'],
        'ulmus': ['Ульмус', 'Дерево'],
        'seirus': ['Сейрус', 'Русалка', 'Аквамен'],
        'eironn': ['Эйрон', 'Эйронн'],
        'gorvo': ['Горво', 'Черепаха'],
        'lorsan': ['Лорсан', 'Заяц'],
        'saurus': ['Саурус', 'Дракон'],
        'solise': ['Солиса', 'Лиса', 'Лисичка'],
        'pippa': ['Пиппа', 'Пипа', 'Пипка'],
        'grezhul': ['Грежул'],
        'shemira': ['Шемира', 'Шема', 'Шимира', 'Шимка', 'Шима', 'Шемка'],
        'Thoran': ['Торан', 'Король'],
        'isabella': ['Изабелла', 'Изабела', 'Магичка с книжкой'],
        'nara': ['Нара'],
        'ferael': ['Фераэль', 'Фарель', 'Форель'],
        'baden': ['Баден', 'Бадэн'],
        'kelthur': ['Кельтур', 'Челик с сюрикеном', 'Чувак с сюрикеном', 'Мужик с сюрикеном'],
        'silas': ['Сайлас', 'Сайлос', 'Сасайлас'],
        'oden': ['Оден', 'Одэн'],
        'izold': ['Изольд'],
        'torne': ['Торн'],
        'daimon': ['Деймон', 'Дэймон', 'Демон', 'Димон'],
        'theowyn': ['Теовин', 'Тэовин'],
        'nakoruru': ['Накоруру'],
        'arthur': ['Артур'],
        'ukyo': ['Юкио', 'Самурай'],
        'ezio': ['Эцио', 'Эйцо'],
        'albedo': ['Альбедо'],
        'ainz_ooal_gown': ['Аинз Оал Гоун', 'Аинз', 'Айнз']
    },
    'tier_lists':
    {
        'pve': {'S+': ['talene', 'tasi', 'rowan', 'mehira', 'twins', 'daimon', 'eironn', 'ezizh'],
                'S': ['athalia', 'rosaline', 'lyca', 'ferael', 'thoran', 'safiya', 'gwyneth', 'izold', 'saurus', 'shemira', 'lucius'],
                'S-': ['nemora', 'khazard', 'orthros', 'nara', 'wu_kong', 'mezoth', 'arthur', 'skreg', 'skriath', 'flora'],
                'A+': ['fawkes', 'hendric', 'oden', 'nakoruru', 'lorsan', 'gorvo', 'drez', 'numisu', 'cecilia', 'brutus', 'belinda'],
                'A': ['tidus', 'kelthur', 'estrilda'],
                'A-': ['warek', 'grezhul'],
                'B+': ['theowyn', 'vurk', 'baden'],
                'B': ['khasos', 'ukio', 'solise', 'anoki', 'torne', 'ezio', ' satrana', 'kaz'],
                'C': ['isabella', 'ulmus', 'seirus', 'oscar', 'antandra'],
                'D': ['thane', 'rigby', 'raine']
            
        },
        'pvp': {'S+': ['talene', 'tasi', 'rowan', 'twins', 'nemora', 'lucius', 'athalia', 'brutus', 'shemira'],
                'S': ['rosaline', 'ferael', 'safiya', 'mehira', 'hendric', 'nara', 'kaz', 'ezizh', 'lyca', 'fawkes', 'ulmus'],
                'A': ['kelthur', 'baden', 'belinda', 'khasos', 'thoran', 'thane', 'raine', 'estrilda', 'seirus', 'isabella', 'warek'],
                'B': ['vurk', 'izold', 'gorvo', 'tidus', 'numisu', 'grezhul', 'skreg']
            
        }
    }
}
